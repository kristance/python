# %%
# folium은 Leaflet.js를 이용해서 위치 좌표계 값을 지도위에 시각화 할 수 있다.
import folium

# %%
#folium의 Map 클래스의 location 속성으로 지정한 위치를 중심으로 하는 zoom_start 속성으로
#지정한 배율을 사용하는 지도를 만든다.
#folium.Map(location=[위도, 경도], zoom_start=배율)
folium_map = folium.Map(location=[37.569147, 126.984695], zoom_start=18)
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_715d5460882e574f939e85f1f0c081a1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_715d5460882e574f939e85f1f0c081a1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_715d5460882e574f939e85f1f0c081a1 = L.map(
#                 &quot;map_715d5460882e574f939e85f1f0c081a1&quot;,
#                 {
#                     center: [37.569147, 126.984695],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_898bd9591ae78a3376b62310fa7a5d1f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_715d5460882e574f939e85f1f0c081a1);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium_map = folium.Map(location=[37.569147, 126.984695], zoom_start=14)

#folium의 Marker 클래스의 location 속성으로 지정한 위치에 마커를 만든다.
# 마커는 add_to() 메소드로 지도에 추가한다.
#folium의 Marker 클래스의 popup 속성으로 마커를 클릭했을때 표시할 문자열을 지정할 수 있다.
folium.Marker(location=[37.57856527,126.97695439], popup='경복궁 근정전').add_to(folium_map)
folium.Marker(location=[37.56595852,126.97416479], popup='덕수궁 해시계').add_to(folium_map)
folium.Marker(location=[37.5787512,126.9948775], popup='창경궁').add_to(folium_map)
folium.Marker(location=[37.57943198,126.99104344], popup='창덕궁').add_to(folium_map)
folium.Marker(location=[37.57422213,126.99352068], popup='종묘').add_to(folium_map)
folium.Marker(location=[37.576034,126.98705201], popup='운현궁').add_to(folium_map)

# 마커를 클릭했을 때 팝업되는 말풍선 크기는 folium의 Popup 클래스의 max_width 속성으로 지정할 수 있다.
popup = folium.Popup('영풍문고 - 종로본점다아아아아아아', max_width=200)
folium.Marker(location=[37.56991173,126.98241074], popup=popup).add_to(folium_map)

#save() 메소드로 지도를 html 파일로 저장할 수 있다.
folium_map.save('./output/foliumMap.htm')
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f463f71613e2d46ea1c2c3b03901209d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f463f71613e2d46ea1c2c3b03901209d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f463f71613e2d46ea1c2c3b03901209d = L.map(
#                 &quot;map_f463f71613e2d46ea1c2c3b03901209d&quot;,
#                 {
#                     center: [37.569147, 126.984695],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_34d1b702f4dc3578eb2809bbc4912f06 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f463f71613e2d46ea1c2c3b03901209d);
#
#
#             var marker_0369d47b1533831ed6538f7438446fb3 = L.marker(
#                 [37.57856527, 126.97695439],
#                 {}
#             ).addTo(map_f463f71613e2d46ea1c2c3b03901209d);
#
#
#         var popup_495b26aeb6822ca0381b860bb74e4ec0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1c9b1fb19f7e3049b2891f1a14c04c13 = $(`&lt;div id=&quot;html_1c9b1fb19f7e3049b2891f1a14c04c13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경복궁 근정전&lt;/div&gt;`)[0];
#             popup_495b26aeb6822ca0381b860bb74e4ec0.setContent(html_1c9b1fb19f7e3049b2891f1a14c04c13);
#
#
#         marker_0369d47b1533831ed6538f7438446fb3.bindPopup(popup_495b26aeb6822ca0381b860bb74e4ec0)
#         ;
#
#
#
#
#             var marker_2a243c0ba5d2b293b8b135b1db3d8cf7 = L.marker(
#                 [37.56595852, 126.97416479],
#                 {}
#             ).addTo(map_f463f71613e2d46ea1c2c3b03901209d);
#
#
#         var popup_3a2ae1c374a81851d04696f24f9c073b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3d35bfd73b7add02ec83b361a53048f9 = $(`&lt;div id=&quot;html_3d35bfd73b7add02ec83b361a53048f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;덕수궁 해시계&lt;/div&gt;`)[0];
#             popup_3a2ae1c374a81851d04696f24f9c073b.setContent(html_3d35bfd73b7add02ec83b361a53048f9);
#
#
#         marker_2a243c0ba5d2b293b8b135b1db3d8cf7.bindPopup(popup_3a2ae1c374a81851d04696f24f9c073b)
#         ;
#
#
#
#
#             var marker_29c06289bcad3d873150e3ede682223b = L.marker(
#                 [37.5787512, 126.9948775],
#                 {}
#             ).addTo(map_f463f71613e2d46ea1c2c3b03901209d);
#
#
#         var popup_c11b472a025c7114de2fd01f0cac3162 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a320811be706a7f76372da0176ffea01 = $(`&lt;div id=&quot;html_a320811be706a7f76372da0176ffea01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;창경궁&lt;/div&gt;`)[0];
#             popup_c11b472a025c7114de2fd01f0cac3162.setContent(html_a320811be706a7f76372da0176ffea01);
#
#
#         marker_29c06289bcad3d873150e3ede682223b.bindPopup(popup_c11b472a025c7114de2fd01f0cac3162)
#         ;
#
#
#
#
#             var marker_fb233d1b94b4432935f1c80c1b1e0a3f = L.marker(
#                 [37.57943198, 126.99104344],
#                 {}
#             ).addTo(map_f463f71613e2d46ea1c2c3b03901209d);
#
#
#         var popup_a04ee75db688264f55c3b096d7ceb960 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d45df0e301d8a4518659efdb414103b4 = $(`&lt;div id=&quot;html_d45df0e301d8a4518659efdb414103b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;창덕궁&lt;/div&gt;`)[0];
#             popup_a04ee75db688264f55c3b096d7ceb960.setContent(html_d45df0e301d8a4518659efdb414103b4);
#
#
#         marker_fb233d1b94b4432935f1c80c1b1e0a3f.bindPopup(popup_a04ee75db688264f55c3b096d7ceb960)
#         ;
#
#
#
#
#             var marker_1d728934b13adaa555a31e975e420d19 = L.marker(
#                 [37.57422213, 126.99352068],
#                 {}
#             ).addTo(map_f463f71613e2d46ea1c2c3b03901209d);
#
#
#         var popup_d3a53203a51a71dbd8ef5ae811491809 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ff8c53e001619cc55a2d7220c1afaa39 = $(`&lt;div id=&quot;html_ff8c53e001619cc55a2d7220c1afaa39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;종묘&lt;/div&gt;`)[0];
#             popup_d3a53203a51a71dbd8ef5ae811491809.setContent(html_ff8c53e001619cc55a2d7220c1afaa39);
#
#
#         marker_1d728934b13adaa555a31e975e420d19.bindPopup(popup_d3a53203a51a71dbd8ef5ae811491809)
#         ;
#
#
#
#
#             var marker_61d5eb8094bc00bda62f874aca57d40d = L.marker(
#                 [37.576034, 126.98705201],
#                 {}
#             ).addTo(map_f463f71613e2d46ea1c2c3b03901209d);
#
#
#         var popup_6d4487369813c0bba8cd3a56e270488c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_9664f70c02d5ca8547452a35e013191f = $(`&lt;div id=&quot;html_9664f70c02d5ca8547452a35e013191f&quot

# %%
folium_map = folium.Map(location=[37.569147, 126.984695], zoom_start=14)

# folium의 Icon 클래스의 color 속성으로  마커의 색상과 icon 속성으로 아이콘 모양을 지정할 수 있다.
# 마커 색상과 아이콘 모양을 변경하려면 folium의 Marker 클래스의 icon 속성에 Icon 객체를 지정하면 된다.
# 색상 이름 리스트
# 'red', 'blue', 'green', 'purple', 'orange', 'darkred', 'lightred',
#    'beige', 'darkblue', 'darkgreen', 'cadetblue', 'darkpurple', 'white',
#     'pink', 'lightblue', 'lightgreen', 'gray', 'black', 'lightgray'
# 마커에 표시할 아이콘은 bootstrap3에서 제공하는 glyphicons에서 찾을 수 있다. 가능유무는 실행해봐야암.
# https://getbootstrap.com/docs/3.3/components/

folium.Marker(location=[37.57856527,126.97695439], popup='경복궁 근정전',
            icon=folium.Icon(color='purple',icon='glass')).add_to(folium_map)
folium.Marker(location=[37.56595852,126.97416479], popup='덕수궁 해시계',
             icon=folium.Icon(color='cadetblue', icon='home')).add_to(folium_map)
folium.Marker(location=[37.5787512,126.9948775], popup='창경궁',
             icon=folium.Icon(color='lightred', icon='time')).add_to(folium_map)
folium.Marker(location=[37.57943198,126.99104344], popup='창덕궁',
             icon=folium.Icon(color='orange', icon='film')).add_to(folium_map)
folium.Marker(location=[37.57422213,126.99352068], popup='종묘',
             icon=folium.Icon(color='darkgreen', icon='remove')).add_to(folium_map)
folium.Marker(location=[37.576034,126.98705201], popup='운현궁',
             icon=folium.Icon(color='gray', icon='music')).add_to(folium_map)

# 마커를 클릭했을 때 팝업되는 말풍선 크기는 folium의 Popup 클래스의 max_width 속성으로 지정할 수 있다.
popup = folium.Popup('영풍문고 - 종로본점다아아아아아아', max_width=200)
folium.Marker(location=[37.56991173,126.98241074], popup=popup,
             icon=folium.Icon(color='red', icon='user')).add_to(folium_map)

#save() 메소드로 지도를 html 파일로 저장할 수 있다.
folium_map.save('./output/foliumMap2.htm')
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2bdc8a906787539483f5a1c44c08adde {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2bdc8a906787539483f5a1c44c08adde&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2bdc8a906787539483f5a1c44c08adde = L.map(
#                 &quot;map_2bdc8a906787539483f5a1c44c08adde&quot;,
#                 {
#                     center: [37.569147, 126.984695],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3e0a0d624f2a6ede52d271e4bcf24992 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2bdc8a906787539483f5a1c44c08adde);
#
#
#             var marker_dae666a72205e6b78acb4f2971803de2 = L.marker(
#                 [37.57856527, 126.97695439],
#                 {}
#             ).addTo(map_2bdc8a906787539483f5a1c44c08adde);
#
#
#             var icon_23b7232a497affd99c165162a2375b5c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glass&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_dae666a72205e6b78acb4f2971803de2.setIcon(icon_23b7232a497affd99c165162a2375b5c);
#
#
#         var popup_78c2ef5ee2305d81f70c30582a091f39 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_881266dc84e928c4ced3d5b8bc982233 = $(`&lt;div id=&quot;html_881266dc84e928c4ced3d5b8bc982233&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경복궁 근정전&lt;/div&gt;`)[0];
#             popup_78c2ef5ee2305d81f70c30582a091f39.setContent(html_881266dc84e928c4ced3d5b8bc982233);
#
#
#         marker_dae666a72205e6b78acb4f2971803de2.bindPopup(popup_78c2ef5ee2305d81f70c30582a091f39)
#         ;
#
#
#
#
#             var marker_165756b7cac688b86955ff9b7d59a064 = L.marker(
#                 [37.56595852, 126.97416479],
#                 {}
#             ).addTo(map_2bdc8a906787539483f5a1c44c08adde);
#
#
#             var icon_573f39b21b7af7181719858d2dae741f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_165756b7cac688b86955ff9b7d59a064.setIcon(icon_573f39b21b7af7181719858d2dae741f);
#
#
#         var popup_ef9653f0e6e0b745f76e1a24f60a90b2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_906123387b0e0b4e0fca0f3f0e5dfe90 = $(`&lt;div id=&quot;html_906123387b0e0b4e0fca0f3f0e5dfe90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;덕수궁 해시계&lt;/div&gt;`)[0];
#             popup_ef9653f0e6e0b745f76e1a24f60a90b2.setContent(html_906123387b0e0b4e0fca0f3f0e5dfe90);
#
#
#         marker_165756b7cac688b86955ff9b7d59a064.bindPopup(popup_ef9653f0e6e0b745f76e1a24f60a90b2)
#         ;
#
#
#
#
#             var marker_710223e5ec90d70c9cf1d403ddf816eb = L.marker(
#                 [37.5787512, 126.9948775],
#                 {}
#             ).addTo(map_2bdc8a906787539483f5a1c44c08adde);
#
#
#             var icon_7f208ba64550eeaca52d12617b2a7766 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;time&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_710223e5ec90d70c9cf1d403ddf816eb.setIcon(icon_7f208ba64550eeaca52d12617b2a7766);
#
#
#         var popup_89f1bfb164886e07fb19984f8322b76e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_dec8895d624fd67a31fee788d5311e35 = $(`&lt;div id=&quot;html_dec8895d624fd67a31fee788d5311e35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;창경궁&lt;/div&gt;`)[0];
#             popup_89f1bfb164886e07fb19984f8322b76e.setContent(html_dec8895d624fd67a31fee788d5311e35);
#
#
#         marker_710223e5ec90d70c9cf1d403ddf816eb.bindPopup(popup_89f1bfb164886e07fb19984f8322b76e)
#         ;
#
#
#
#
#             var marker_9e1df6de9ac73018a3bf766bb9ee4912 = L.marker(
#                 [37.57943198, 126.99104344],
#                 {}
#             ).addTo(map_2bdc8a906787539483f5a1c44c08adde);
#
#
#             var icon_6b19f33e06dce0bce1b74477a3da8ff5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;film&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9e1df6de9ac73018a3bf766bb9ee4912.setIcon(icon_6b19f33e06

# %%
folium_map = folium.Map(location=[37.569147, 126.984695], zoom_start=12)

#folium의 CircleMarker 클래스로 원형 마커를 만들 수 있다.
#radius 속성으로 마커로 표시되는 원의 반지를 지정한다.
#color 속성으로 원의 선 색상을, fill_color속성으로 원 내부에 채울 색상을 지정할 수 있다.

folium.CircleMarker(location=[37.56595852,126.97416479], popup='덕수궁 해시계',
                   radius=50, color='thistle', fill_color='purple').add_to(folium_map)

popup = folium.Popup('영풍문고 - 종로본점다아아아아아아', max_width=200)
folium.CircleMarker(location=[37.56991173,126.98241074], popup=popup,
                   radius=50, color='gray', fill_color='yellow').add_to(folium_map)

folium_map.save('./output/foliumMap3.htm')
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_37395062debe142ea92c1a719bf7a464 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_37395062debe142ea92c1a719bf7a464&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_37395062debe142ea92c1a719bf7a464 = L.map(
#                 &quot;map_37395062debe142ea92c1a719bf7a464&quot;,
#                 {
#                     center: [37.569147, 126.984695],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5f4ab1049183f4a4b23e0a0b2a9afd8e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_37395062debe142ea92c1a719bf7a464);
#
#
#             var circle_marker_b593afd16eab47746a9bd44fcebc985d = L.circleMarker(
#                 [37.56595852, 126.97416479],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;thistle&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_37395062debe142ea92c1a719bf7a464);
#
#
#         var popup_16c32da4936b0b07ce8ab3e70afbe3ea = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b091ef2276c87a069bc50004192c0f75 = $(`&lt;div id=&quot;html_b091ef2276c87a069bc50004192c0f75&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;덕수궁 해시계&lt;/div&gt;`)[0];
#             popup_16c32da4936b0b07ce8ab3e70afbe3ea.setContent(html_b091ef2276c87a069bc50004192c0f75);
#
#
#         circle_marker_b593afd16eab47746a9bd44fcebc985d.bindPopup(popup_16c32da4936b0b07ce8ab3e70afbe3ea)
#         ;
#
#
#
#
#             var circle_marker_9abc61c4e2b78391898dc86aedea23b0 = L.circleMarker(
#                 [37.56991173, 126.98241074],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_37395062debe142ea92c1a719bf7a464);
#
#
#         var popup_0e5839d9935a469595e05f246bd710b9 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#             var html_0874840bbeb802a815828a0e6b2e60e7 = $(`&lt;div id=&quot;html_0874840bbeb802a815828a0e6b2e60e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;영풍문고 - 종로본점다아아아아아아&lt;/div&gt;`)[0];
#             popup_0e5839d9935a469595e05f246bd710b9.setContent(html_0874840bbeb802a815828a0e6b2e60e7);
#
#
#         circle_marker_9abc61c4e2b78391898dc86aedea23b0.bindPopup(popup_0e5839d9935a469595e05f246bd710b9)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
